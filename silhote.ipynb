# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
x1=np.array([1,2,3,1,5,6,5,5,6,7,8,0,7,9])
x2=np.array([1,3,2,2,8,6,7,6,7,1,2,1,1,3])
plt.plot(x1,x2,'ro')
plt.show()

# %%
x=np.array([x1,x2]).T
x
# Out:
# array([[1, 1],
#        [2, 3],
#        [3, 2],
#        [1, 2],
#        [5, 8],
#        [6, 6],
#        [5, 7],
#        [5, 6],
#        [6, 7],
#        [7, 1],
#        [8, 2],
#        [0, 1],
#        [7, 1],
#        [9, 3]])

# %%
plt.subplot(3,2,1)
plt.xlim([0,10])
plt.ylim([0,10])
plt.title('instances')
plt.scatter(x1,x2)
